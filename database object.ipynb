-- %%
create schema if not exists datamastser.bronze;

-- %% [markdown]
-- ![](/Volumes/datamastser/bronze/image/Jun_2027_Salary_slip.png)

-- %%
create table if not exists datamastser.bronze.df (id string, name string,age int);
insert into datamastser.bronze.df values ('1','John',25),('2','Jane',30);

-- %%
select * from datamastser.bronze.df;

-- %%
--hi welcome
